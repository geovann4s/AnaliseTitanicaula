# %%
graph TD
    %% Nível Principal
    Relatorios[RELATÓRIOS DE SUSTENTABILIDADE / INTEGRADOS <br/> 2019 - 2024] --> Categorias[CATEGORIAS DE ANÁLISE]

    %% Divisão das Categorias
    Categorias --> Potencialidades[POTENCIALIDADES CORPORATIVAS <br/> 'Discurso de Sucesso']
    Categorias --> Contingencias[CONTINGÊNCIAS E DESAFIOS <br/> 'A Realidade/Problemas']

    %% Subcategorias de Potencialidades
    Potencialidades --> Sub1[1. Protagonismo ESG]
    Potencialidades --> Sub2[2. Inovação Regenerativa]
    Potencialidades --> Sub3[3. Engajamento Social]

    %% Temas de Potencialidades
    Sub1 --- T1[Liderança em Rankings <br/> Certificação Empresa B <br/> Prémios de Ética]
    Sub2 --- T2[Economia Circular / Refis <br/> Biocosméticos <br/> IP&L Positivo]
    Sub3 --- T3[Projetos na Amazónia <br/> Educação de Consultoras <br/> Diversidade e Inclusão]

    %% Subcategorias de Contingências
    Contingencias --> Sub4[1. Vulnerabilidade Operacional]
    Contingencias --> Sub5[2. Crises Reputacionais/Judiciais]
    Contingencias --> Sub6[3. Impactos Negativos - GRI]

    %% Temas de Contingências
    Sub4 --- T4[Reestruturação de Capital <br/> Endividamento <br/> Venda de Marcas Globais]
    Sub5 --- T5[Chapter 11 de Subsidiárias <br/> Processos Trabalhistas <br/> Metas não atingidas]
    Sub6 --- T6[Emissões de Carbono <br/> Geração de Resíduos <br/> Consumo de Água]

    %% Estilização
    style Relatorios fill:#f9f9f9,stroke:#333,stroke-width:2px
    style Potencialidades fill:#e1f5fe,stroke:#01579b
    style Contingencias fill:#ffebee,stroke:#b71c1c
# Out:
#   Cell In[1], line 1
#     graph TD
#           ^
# SyntaxError: invalid syntax
